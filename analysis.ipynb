# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df=pd.read_csv("kenya food data.csv")

# %%
df
# Out:
#              date         admin1      admin2              market  latitude  \
# 0           #date     #adm1+name  #adm2+name    #loc+market+name  #geo+lat
# 1      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# 2      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# 3      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# 4      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# ...           ...            ...         ...                 ...       ...
# 18316  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18317  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18318  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18319  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18320  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
#
# ...

# %%
df.isnull().sum()
# Out:
# date            0
# admin1          0
# admin2          0
# market          0
# latitude        0
# longitude       0
# category      570
# commodity    6984
# unit            0
# priceflag       0
# pricetype       0
# currency        0
# price           0
# usdprice        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df["commodity"].value_counts()
# Out:
# Beans              3727
# Maize              3161
# Potatoes           1629
# Rice                829
# Oil (vegetable)     655
# Sugar               473
# Bread               184
# Milk                184
#                      83
# #item+name            1
# Name: commodity, dtype: int64

# %%
df
# Out:
#              date         admin1      admin2              market  latitude  \
# 0           #date     #adm1+name  #adm2+name    #loc+market+name  #geo+lat
# 1      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# 2      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# 3      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# 4      15/01/2006          Coast     Mombasa             Mombasa     -4.05
# ...           ...            ...         ...                 ...       ...
# 18313  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18314  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18317  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18318  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
# 18319  15/02/2024  North Eastern     Garissa  Dagahaley (Daadab)  0.185656
#
#        longitude            category        commodity        unit  \
# ...

# %%
df.drop("category",axis=1,inplace=True)

# %%
df.to_csv("cleaned data.csv")
